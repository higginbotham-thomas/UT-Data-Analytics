# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
#Reading the dataset
df = pd.read_csv('Demographic_Data.csv')

# %%
#Dataset
df
# Out:
#        in-store  age  items   amount  region
# 0             0   37      4   281.03       2
# 1             0   35      2   219.51       2
# 2             1   45      3  1525.70       4
# 3             1   46      3   715.25       3
# 4             1   33      4  1937.50       1
# ...         ...  ...    ...      ...     ...
# 79995         1   71      3   558.82       1
# 79996         0   59      7  1932.00       3
# 79997         0   54      1   414.16       2
# 79998         1   49      4   335.32       1
# 79999         1   30      1   527.12       3
#
# [80000 rows x 5 columns]

# %%
#Display first 5 rows
df.head()
# Out:
#    in-store  age  items   amount  region
# 0         0   37      4   281.03       2
# 1         0   35      2   219.51       2
# 2         1   45      3  1525.70       4
# 3         1   46      3   715.25       3
# 4         1   33      4  1937.50       1

# %%
#Info on the data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   in-store  80000 non-null  int64
#  1   age       80000 non-null  int64
#  2   items     80000 non-null  int64
#  3   amount    80000 non-null  float64
#  4   region    80000 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 3.1 MB

# %%
#Description of data
df.describe()
# Out:
#            in-store           age         items        amount        region
# count  80000.000000  80000.000000  80000.000000  80000.000000  80000.000000
# mean       0.500000     45.757925      4.504975    835.919670      2.675000
# std        0.500003     15.715679      2.061238    721.273736      1.126672
# min        0.000000     18.000000      1.000000      5.004700      1.000000
# 25%        0.000000     33.000000      3.000000    285.140000      2.000000
# 50%        0.500000     45.000000      4.000000    582.315000      3.000000
# 75%        1.000000     56.000000      6.000000   1233.700000      4.000000
# max        1.000000     85.000000      8.000000   3000.000000      4.000000

# %%
#Drop duplicates
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# in-store    0
# age         0
# items       0
# amount      0
# region      0
# dtype: int64

# %%
df.dtypes
# Out:
# in-store      int64
# age           int64
# items         int64
# amount      float64
# region        int64
# dtype: object

# %%
df.dtypes.index
# Out:
# Index(['in-store', 'age', 'items', 'amount', 'region'], dtype='object')

# %%
#Display the number of entries for each region
df['region'].value_counts()
# Out:
# 4    25988
# 2    19994
# 3    18000
# 1    15997
# Name: region, dtype: int64

# %%
#Correlation
df.corr()
# Out:
#           in-store       age     items    amount    region
# in-store  1.000000 -0.178180 -0.003897 -0.085573 -0.133171
# age      -0.178180  1.000000  0.000657 -0.282033 -0.235370
# items    -0.003897  0.000657  1.000000  0.000384 -0.001904
# amount   -0.085573 -0.282033  0.000384  1.000000  0.403486
# region   -0.133171 -0.235370 -0.001904  0.403486  1.000000

# %%
#Covariance
df.cov()
# Out:
#            in-store          age     items         amount      region
# in-store   0.250003    -1.400071 -0.004017     -30.860425   -0.075019
# age       -1.400071   246.966189  0.021270   -3196.782841   -4.167305
# items     -0.004017     0.021270  4.248751       0.570791   -0.004421
# amount   -30.860425 -3196.782841  0.570791  520221.252295  327.874873
# region    -0.075019    -4.167305 -0.004421     327.874873    1.269321

# %%
#Plotting Transaction Counts for each Region
plt.title("Transaction counts for each region")
sns_plot=sns.countplot(data=df,x='region')
fig=sns_plot.get_figure()

# %%
#Plotting total counts by age
plt.figure(figsize=(20,5))
plt.title("Total counts by age")
sns_plot=sns.countplot(data=df,x='age')
fig=sns_plot.get_figure()

# %%
#Plotting total count for number of items
plt.title("Total counts for items purchased per transaction")
sns_plot=sns.countplot(data=df,x='items')
fig=sns_plot.get_figure()

# %%
#Boxplot for each data category
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
#Histogram for age
df['age'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
#Histogram for amounts
df['amount'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
#Boxplot to illustrate distribution of amount
sns.catplot(x= 'amount', kind = 'box', data= df)

# %%
#Scatter plot of age and amount, based on in-store
sns.relplot(x= 'age', y= 'amount', hue='in-store', data= df)

# %%
#Scatter plot of region and amount, based on in-store
sns.relplot(x= 'region', y= 'amount', hue='in-store', data= df)

# %%
#Linear plot of region against amount
sns.lmplot('region', 'amount', data= df)
# Out:
# /Users/thomashigginbotham/opt/anaconda3/envs/Course1env/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Total amounts sold per region and shown in millions
Amount_Sold = df.groupby('region')['amount'].sum()
Amount_Sold/1e6
# Out:
# region
# 1    11.917620
# 2     5.040442
# 3    16.523453
# 4    33.366990
# Name: amount, dtype: float64

# %%
#Grouping by region to show total amounts sold per region 
Amount_sold= df.groupby['region']['amount'].sum()
Amount_sold.plot(title= 'Total Amounts by Region', kind= 'bar', ylabel= 'Total amounts sold in tens of millions',
                xlabel= 'Region')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 2>()
#       1 #Grouping by region to show total amounts sold per region
# ----> 2 Amount_sold= df.groupby['region']['amount'].sum()
#       3 Amount_sold.plot(title= 'Total Amounts by Region', kind= 'bar', ylabel= 'Total amounts sold in tens of millions',
#       4                 xlabel= 'Region')
#
# TypeError: 'method' object is not subscriptable

# %%
#Average age from sales to determine potential in targeted marketing
Average_age = df.groupby('region')['age'].mean()
Average_age

# %%
#Average Age by Region
Average_age = df.groupby('region')['age'].mean()
Average_age.plot(kind='bar', title="Average Consumer Age by Region", ylabel='Average Age', xlabel='Region')

# %%
#Average Purchase Amount by Age
Average_amount = df.groupby('age')['amount'].mean()
Average_amount

# %%
#Average Purchase Amount by Age
Average_amount = df.groupby('age')['amount'].mean()
Average_amount.plot(kind='bar', title="Average Purchase Amount by Age", ylabel = 'Average Amount Purchased', xlabel='Age',  figsize=(20, 5))

# %%
#Average total transaction amount grouped by number of items in the transaction
Average_items = df.groupby('items')['amount'].mean()
Average_items
